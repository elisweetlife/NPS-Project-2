# %%
# Mapping lets you format an entire DataFrame
import pandas as pd 

campgrounds = "campgrounds.csv"
camp_ground_df = pd.read_csv(campgrounds)
camp_ground_df
# Out:
#     Unnamed: 0 parkCode                                             name  \
# 0            0     arch                         Devils Garden Campground
# 1            1     biso                           Bandy Creek Campground
# 2            2     chis                        Anacapa Island Campground
# 3            3     chis                  Santa Barbara Island Campground
# 4            4     crla                        Mazama Village Campground
# 5            5     crla                            Lost Creek Campground
# 6            6     dena                                      Igloo Creek
# 7            7     dena                                      Wonder Lake
# 8            8     dena                                      Riley Creek
# 9            9     dena                                     Savage River
# 10          10     dewa                     Rivers Bend Group Campground
# 11          11     glba                         Bartlett Cove Campground
# ...

# %%
camp_ground_df.name.count()
# Out:
# 50

# %%
alerts = "alerts.csv"
alerts_df = pd.read_csv(alerts)
alerts_df.head()
# Out:
#    Unnamed: 0      category  \
# 0           0  Park Closure
# 1           1  Park Closure
# 2           2   Information
# 3           3  Park Closure
# 4           4  Park Closure
#
#                                          description  \
# 0  As of Monday, June 8, 2020, the Memorial Build...
# 1  The Precipice Trail, Jordan Cliffs Trail, Vall...
# 2  Island Explorer fare-free bus service for Acad...
# 3  Western Mountain Roads north of Seal Cove Road...
# 4  The Park Loop Road and most hiking trails are ...
#
#                                     id parkCode  \
# 0  258E8D7C-BF5C-BC56-B768A56DB7A449DE     abli
# 1  080DA2BA-155D-451F-67E747D79A312D12     acad
# 2  C75721EB-0BD4-AEA1-5673D073F24D8F56     acad
# 3  CB8E5C25-067E-433A-9F8F3C4D3FCB0EC4     acad
# 4  E83E1FF5-BFDF-0A67-6C51BE900BFD0D86     acad
#
#                                                title  \
# 0                         PARK ALERT! March 18, 2020
# 1  Wildlife Closure: Several Trails Are Off Limit...
# ...
